# %% [markdown]
# <a href="https://colab.research.google.com/github/sebagit914/Challenge01/blob/master/bike_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
filename = '/content/drive/MyDrive/PTDataScience/PandasForDataManipulation/RailsToTrails_National_Count_Data_week.xlsx'
bike_df = pd.read_excel(filename)
bike_df.head()
# Out:
#   Timeframe    Week of  ...  Unnamed: 8  Unnamed: 9
# 0    Week 1 2020-12-30  ...         NaN         NaN
# 1    Week 2 2020-01-06  ...         NaN         NaN
# 2    Week 3 2020-01-13  ...         NaN         NaN
# 3    Week 4 2020-01-20  ...         NaN         NaN
# 4    Week 5 2020-01-27  ...         NaN         NaN
#
# [5 rows x 10 columns]

# %%
data2 = bike_df.copy()

# %% [markdown]
# 01.Selecciona solo los datos después del 31 de julio de 2020.
#
# 02.Selecciona solo los datos donde la columna «Change 2019-2020» sea mayor que 100% (más de 1).
#
# 03.Selecciona esto! ¿Hubo alguna semana en la segunda mitad del año (luego del 31 de julio de 2020) donde el cambio fuera mayor que 100%?

# %%
data2.head()
# Out:
#   Timeframe    Week of  ...  Unnamed: 8  Unnamed: 9
# 0    Week 1 2020-12-30  ...         NaN         NaN
# 1    Week 2 2020-01-06  ...         NaN         NaN
# 2    Week 3 2020-01-13  ...         NaN         NaN
# 3    Week 4 2020-01-20  ...         NaN         NaN
# 4    Week 5 2020-01-27  ...         NaN         NaN
#
# [5 rows x 10 columns]

# %%
filtro1 = (data2['Week of'] > '2020-07-31')
filtro2_df=data2.loc[filtro1]
filtro2_df.head()
# Out:
#    Timeframe    Week of  ...  Unnamed: 8  Unnamed: 9
# 0     Week 1 2020-12-30  ...         NaN         NaN
# 31   Week 32 2020-08-03  ...         NaN         NaN
# 32   Week 33 2020-08-10  ...         NaN         NaN
# 33   Week 34 2020-08-17  ...         NaN         NaN
# 34   Week 35 2020-08-24  ...         NaN         NaN
#
# [5 rows x 10 columns]

# %%
filtro1 = (data2['Change 2019-2020'] > 1)
filtro2_df=data2.loc[filtro1]
filtro2_df.head()
# Out:
#    Timeframe    Week of  ...  Unnamed: 8  Unnamed: 9
# 7     Week 8 2020-02-17  ...         NaN         NaN
# 11   Week 12 2020-03-16  ...         NaN         NaN
# 12   Week 13 2020-03-23  ...         NaN         NaN
# 13   Week 14 2020-03-30  ...         NaN         NaN
# 14   Week 15 2020-04-06  ...         NaN         NaN
#
# [5 rows x 10 columns]

# %%
filtro1 = (data2['Week of'] > '2020-07-31')
filtro2 = (data2['Change 2019-2020'] > 1)
filtro3_df= data2.loc[filtro1 & filtro2,:]
filtro3_df.head()
# Out:
# Empty DataFrame
# Columns: [Timeframe, Week of,  2019 counts (31 counters),  2020 counts (31 counters), 2021 Counts, Change 2019-2020, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9]
# Index: []
