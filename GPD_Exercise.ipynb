# %% [markdown]
# <a href="https://colab.research.google.com/github/sebagit914/Challenge01/blob/master/GPD_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# El ejercicio comienza con la importación de las librerias necesarias para su desarrollo

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Al abrir el archivo CSV arroja error, debido a que los datos no están estructurados por columnas y filas de manera legible.
#
# El método skiprows soluciona este problema eliminando las primeras 4 filas del archivo CSV

# %%
df = pd.read_csv('GDP.csv', skiprows = 4)
df
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %% [markdown]
# ## TAREA
#
# Estructurar los datos con las siguientes columnas:
# - Nombre del País
# - Código del País
# - Años
# - PIB

# %%
df.shape
df2 = df1

# %% [markdown]
# El primer paso es eliminar columnas que no son útiles para un análisis posterior

# %%
#Enfoque 1:: Método Drop

df2 = df2.drop(columns = ['Indicator Name', 'Indicator Code', 'Unnamed: 62'])
df2.head()
# Out:
#   Country Name Country Code          1960          1961          1962  \
# 0        Aruba          ABW           NaN           NaN           NaN
# 1  Afghanistan          AFG  5.377778e+08  5.488889e+08  5.466667e+08
# 2       Angola          AGO           NaN           NaN           NaN
# 3      Albania          ALB           NaN           NaN           NaN
# 4      Andorra          AND           NaN           NaN           NaN
#
#            1963          1964          1965          1966          1967  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
#            2008          2009          2010          2011          2012  \
# ...

# %% [markdown]
# Corroboramos de que las filas efectivamente se eliminaron, quedando 60 filas.

# %%
df2.shape
# Out:
# (264, 60)

# %% [markdown]
# El objetivo de este segundo paso, es cambiar el nombre de Country Name a Pais; Country Code, Codigo Pais

# %%
df2 = df2.rename(columns = {'Country Name':'Pais','Country Code': 'Codigo Pais' })
df2.head()
# Out:
#           Pais Codigo Pais          1960          1961          1962  \
# 0        Aruba         ABW           NaN           NaN           NaN
# 1  Afghanistan         AFG  5.377778e+08  5.488889e+08  5.466667e+08
# 2       Angola         AGO           NaN           NaN           NaN
# 3      Albania         ALB           NaN           NaN           NaN
# 4      Andorra         AND           NaN           NaN           NaN
#
#            1963          1964          1965          1966          1967  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
#            2008          2009          2010          2011          2012  \
# ...
