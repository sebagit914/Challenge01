# %% [markdown]
# <a href="https://colab.research.google.com/github/sebagit914/Challenge01/blob/master/3_3_Reproducir_inter%C3%A9s_vs_gr%C3%A1fico_principal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Captura de Pantalla 2021-08-26 a la(s) 19.59.29.png](data:image/png;base64,...)

# %% [markdown]
# # 1 - Importar Librerías

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # 2 - Montar volumen Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename = '/content/drive/MyDrive/PTDataScience/PandasForDataManipulation/3º semana/3.2.1.mortage.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#    Month  Starting Balance  Repayment  ...  New Balance  Mortgage Name  Interest Rate
# 0      1         400000.00    1686.42  ...    399313.58        30 Year           0.03
# 1      2         399313.58    1686.42  ...    398625.44        30 Year           0.03
# 2      3         398625.44    1686.42  ...    397935.58        30 Year           0.03
# 3      4         397935.58    1686.42  ...    397243.99        30 Year           0.03
# 4      5         397243.99    1686.42  ...    396550.67        30 Year           0.03
#
# [5 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Month', 'Starting Balance', 'Repayment', 'Interest Paid',
#        'Principal Paid', 'New Balance', 'Mortgage Name', 'Interest Rate'],
#       dtype='object')

# %%
df.shape
# Out:
# (1080, 8)

# %% [markdown]
# # 3 - Filtro al 3% y a 30 años

# %%
filtro_3 = df['Interest Rate'] == 0.03
filtro_30= df['Mortgage Name'] == '30 Year'
filtro_3_30 = df.loc[filtro_3 & filtro_30, : ]
filtro_3_30.head()
# Out:
#    Month  Starting Balance  Repayment  ...  New Balance  Mortgage Name  Interest Rate
# 0      1         400000.00    1686.42  ...    399313.58        30 Year           0.03
# 1      2         399313.58    1686.42  ...    398625.44        30 Year           0.03
# 2      3         398625.44    1686.42  ...    397935.58        30 Year           0.03
# 3      4         397935.58    1686.42  ...    397243.99        30 Year           0.03
# 4      5         397243.99    1686.42  ...    396550.67        30 Year           0.03
#
# [5 rows x 8 columns]

# %%
filtro_3_30 = filtro_3_30[['Month', 'Interest Paid']]
filtro_3_30 = filtro_3_30.assign(acumulado = filtro_3_30['Interest Paid'].cumsum())
del filtro_3_30['Interest Paid']
filtro_3_30
# Out:
#      Month  acumulado
# 0        1    1000.00
# 1        2    1998.28
# 2        3    2994.84
# 3        4    3989.67
# 4        5    4982.77
# ..     ...        ...
# 355    356  207064.13
# 356    357  207080.87
# 357    358  207093.44
# 358    359  207101.82
# 359    360  207106.01
#
# [360 rows x 2 columns]

# %%
meses_30_3 = filtro_3_30.loc[ : ,'Month'].values
acumulado_30_3 = filtro_3_30.loc[ :, 'acumulado'].values

# %% [markdown]
# # 4 -Filtro al 5% y a 30 años

# %%
filtro_5 = df['Interest Rate'] == 0.05
filtro_5_30 = df.loc[filtro_5 & filtro_30, : ]
filtro_5_30.head()
# Out:
#      Month  Starting Balance  ...  Mortgage Name  Interest Rate
# 360      1         400000.00  ...        30 Year           0.05
# 361      2         399519.37  ...        30 Year           0.05
# 362      3         399036.74  ...        30 Year           0.05
# 363      4         398552.10  ...        30 Year           0.05
# 364      5         398065.44  ...        30 Year           0.05
#
# [5 rows x 8 columns]

# %%
filtro_5_30 = filtro_5_30[['Month', 'Interest Paid']]
filtro_5_30 = filtro_5_30.assign(acumulado = filtro_5_30['Interest Paid'].cumsum())
del filtro_5_30['Interest Paid']
filtro_5_30
# Out:
#      Month  acumulado
# 360      1    1666.66
# 361      2    3331.32
# 362      3    4993.97
# 363      4    6654.60
# 364      5    8313.20
# ..     ...        ...
# 715    356  372928.64
# 716    357  372964.02
# 717    358  372990.60
# 718    359  373008.35
# 719    360  373017.23
#
# [360 rows x 2 columns]

# %%
meses_30_5 = filtro_5_30.loc[ : ,'Month'].values
acumulado_30_5 = filtro_5_30.loc[ :, 'acumulado'].values

# %% [markdown]
# # 4 - Gráfico

# %%
plt.plot(meses_30_3, acumulado_30_3, c = "b", label = '30 Year 3% APR') 
plt.plot(meses_30_5, acumulado_30_5, c= "k", label = '30 Year 5% APR')
plt.xlim(left=0,right=360)
plt.ylim(bottom=0,top=400000)
plt.xlabel('Month')
plt.ylabel('Dollar')
plt.title('Cumulative Interest Paid') 
plt.grid()
plt.legend( loc= 'lower right')
